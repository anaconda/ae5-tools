# %%
from src.anaconda.enterprise.sdk.cluster.config import ConfigManager
from src.anaconda.enterprise.sdk.contracts.dto.cluster.options import ClusterOptions

options_dict: dict = {
    "hostname": "xyz.host.local",
    "username": "USERNAME",
    "password": "SECRET-PASSWORD",
}

options: ClusterOptions = ClusterOptions.parse_obj(options_dict)
config: ConfigManager = ConfigManager()

# %%
from src.anaconda.enterprise.sdk.cluster.client import ClusterClient

cluster_client: ClusterClient = ClusterClient(options=options, config=config)

# %%
from src.anaconda.enterprise.sdk.contracts.dto.responses.deployment_token import DeploymentTokenResponse
from src.anaconda.enterprise.sdk.contracts.dto.requests.deployment_token import DeploymentTokenRequest
from src.anaconda.enterprise.sdk.contracts.ae_user_session_command import AEUserSessionCommand

request: DeploymentTokenRequest = DeploymentTokenRequest(ident="a2-75807c920a4a4bbeb6d1f6524c35e89b")
result: DeploymentTokenResponse = cluster_client.call(method=AEUserSessionCommand.DEPLOYMENT_TOKEN, request=request)
print(result)
# Out:
# Connecting to user account jburt@aip.demo.anaconda.com.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x107f01bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='aip.demo.anaconda.com', port=443): Max retries exceeded with url: /auth/realms/AnacondaPlatform/protocol/openid-connect/auth?client_id=anaconda-platform&scope=openid&response_type=code&redirect_uri=https%3A%2F%2Faip.demo.anaconda.com%2Flogin (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x107f01bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 6
#       3 from src.anaconda.enterprise.sdk.contracts.ae_user_session_command import AEUserSessionCommand
#       5 request: DeploymentTokenRequest = DeploymentTokenRequest(ident="a2-75807c920a4a4bbeb6d1f6524c35e89b")
# ----> 6 result: DeploymentTokenResponse = cluster_client.call(method=AEUserSessionCommand.DEPLOYMENT_TOKEN, request=request)
#       7 print(result)
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/cluster/client.py:124, in ClusterClient.call(self, method, *args, **kwargs)
#     121     kwargs.setdefault("format", call_format)
#     123 # Retrieve the proper cluster session object and make the call
# --> 124 result = getattr(cluster_session, method)(*args, **kwargs)
#     126 # Do not perform this processing on converted calls [legacy processing]
#     127 if method in [AEUserSessionCommand.DEPLOYMENT_TOKEN]:
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/user.py:868, in AEUserSession.deployment_token(self, request)
#     867 def deployment_token(self, request: DeploymentTokenRequest) -> DeploymentTokenResponse:
# --> 868     id = self.ident_record("deployment", request.ident)["id"]
#     869     response = self._post(f"deployments/{id}/token", format="json")
#     870     return DeploymentTokenResponse.parse_obj(response)
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/abstract.py:180, in AbstractAESession.ident_record(self, record_type, ident, quiet, **kwargs)
#     178     ident = Identifier.from_string(ident, itype)
#     179     filter = ident.project_filter(itype=itype, ignore_revision=True)
# --> 180 matches = getattr(self, f"{record_type}_list")(filter=filter, **kwargs)
#     181 return self._should_be_one(matches, filter, quiet)
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/user.py:668, in AEUserSession.deployment_list(self, filter, collaborators, k8s, format)
#     667 def deployment_list(self, filter=None, collaborators=False, k8s=False, format=None):
# --> 668     response = self._get_records("deployments", filter=filter, collaborators=collaborators, k8s=k8s)
#     669     return self._format_response(response, format=format)
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/user.py:63, in AEUserSession._get_records(self, endpoint, filter, **kwargs)
#      62 def _get_records(self, endpoint, filter=None, **kwargs):
# ---> 63     return self._api_records("get", endpoint, filter=filter, **kwargs)
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/user.py:54, in AEUserSession._api_records(self, method, endpoint, filter, **kwargs)
#      52     record_type = endpoint.rsplit("/", 1)[-1].rstrip("s")
#      53 for attempt in range(20):
# ---> 54     records = self._api(method, endpoint, **api_kwargs)
#      55     if records or not retry_if_empty:
#      56         break
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/abstract.py:259, in AbstractAESession._api(self, method, endpoint, **kwargs)
#     257 allow_retry = True
#     258 if not self._connected():
# --> 259     self.authorize()
#     260     if self.password is not None:
#     261         allow_retry = False
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/abstract.py:99, in AbstractAESession.authorize(self)
#      97 def authorize(self):
#      98     password = self.password
# ---> 99     self._connect(password)
#     100     if self._connected():
#     101         self._set_header()
#
# File ~/Workbench/Repositories/anaconda.enterprise.sdk/src/anaconda/enterprise/sdk/ae/session/abstract.py:359, in AbstractAESession._connect(self, password)
#     352 params = {
#     353     "client_id": "anaconda-platform",
#     354     "scope": "openid",
#     355     "response_type": "code",
#     356     "redirect_uri": f"https://{self.hostname}/login",
#     357 }
#     358 url = f"https://{self.hostname}/auth/realms/AnacondaPlatform/protocol/openid-connect/auth"
# --> 359 resp = self.session.get(url, params=params)
#     360 match = re.search(r'<form id="kc-form-login".*?action="([^"]*)"', resp.text, re.M)
#     361 if not match:
#     362     # Already logged in, apparently?
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/anaconda.enterprise.sdk/lib/python3.10/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='aip.demo.anaconda.com', port=443): Max retries exceeded with url: /auth/realms/AnacondaPlatform/protocol/openid-connect/auth?client_id=anaconda-platform&scope=openid&response_type=code&redirect_uri=https%3A%2F%2Faip.demo.anaconda.com%2Flogin (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x107f01bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
